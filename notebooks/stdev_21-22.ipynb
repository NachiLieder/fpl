# %%
import pandas as pd
import os
import glob

# %%
path = '../data/2021-22/gws/'
all_files = glob.glob(os.path.join(path, "*.csv"))

df = pd.concat((pd.read_csv(f) for f in all_files), ignore_index=True)

# %%
df
# Out:
#                                 name position            team   xP  assists  \
# 0                        Eric Bailly      DEF         Man Utd  1.4      0.0
# 3                  James Ward-Prowse      MID     Southampton  1.5      0.0
# 4      Bruno Miguel Borges Fernandes      MID         Man Utd  4.6      0.0
# 12         José Diogo Dalot Teixeira      DEF         Man Utd  3.8      0.0
# 13                   Jeffrey Schlupp      MID  Crystal Palace  1.4      0.0
# ...                              ...      ...             ...  ...      ...
# 75306                 Connor Roberts      DEF         Burnley  6.2      0.0
# 75307                 Connor Roberts      DEF         Burnley  6.2      0.0
# 75309                   Adam Webster      DEF        Brighton -1.5      0.0
# 75310                     Phil Foden      MID        Man City  6.0      0.0
# 75312                    Reece James      DEF         Chelsea  0.3      0.0
#
# ...

# %%
df.columns

df.shape, df[df['minutes']>0].shape

df = df[df['minutes']>0]

# %%
df.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
#        'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
#        'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'red_cards', 'round', 'saves', 'selected', 'team_a_score',
#        'team_h_score', 'threat', 'total_points', 'transfers_balance',
#        'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards',
#        'id', 'GW'],
#       dtype='object')

# %%
df.head()

# single = pd.read_csv(path + 'gw1.csv')


df.groupby('element').std()['total_points'].to_csv('stdev_22-23.csv')

# %%
df[df['element']==146]
df.iloc[1]
# Out:
# name                    James Ward-Prowse
# position                              MID
# team                          Southampton
# xP                                    1.5
# assists                               0.0
# bonus                                 0.0
# bps                                   8.0
# clean_sheets                          0.0
# creativity                           20.0
# element                             341.0
# fixture                             151.0
# goals_conceded                        3.0
# goals_scored                          0.0
# ict_index                             4.6
# influence                            10.0
# kickoff_time         2021-12-11T15:00:00Z
# minutes                              90.0
# opponent_team                         1.0
# own_goals                             0.0
# penalties_missed                      0.0
# penalties_saved                       0.0
# red_cards                             0.0
# ...
